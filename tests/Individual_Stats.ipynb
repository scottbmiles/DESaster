# %% [markdown]
# # Individual Charts

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "../Outputs/Output2017-01-17"

# %%
df = pd.read_csv("{}.csv".format(path))

# %%
namedf = df.set_index(keys=df.name)

# %%
name = "MARSHA FULLER"

# %%
namedf.where(namedf.money_search_stop>100)
# Out:
#                    Unnamed: 0  assessment_get  assessment_put  assistance_get  \
# name
# JONE MEHTA                NaN             NaN             NaN             NaN
# MERRY CHAMBERLAIN         NaN             NaN             NaN             NaN
# JEANNIE GIBBS             NaN             NaN             NaN             NaN
# KATHRYN REYES             NaN             NaN             NaN             NaN
# OCTAVIA GOFF              NaN             NaN             NaN             NaN
# TARA HUDSON               NaN             NaN             NaN             NaN
# LASANDRA ESPINO           NaN             NaN             NaN             NaN
# IRA LINK                  NaN             NaN             NaN             NaN
# PIPER SKELTON             NaN             NaN             NaN             NaN
# MARINDA BROCKMAN          NaN             NaN             NaN             NaN
# ELSIE ELLIOTT             NaN             NaN             NaN             NaN
# EMILIA BUCKLEY            NaN             NaN             NaN             NaN
# AISHA PROCTOR             NaN             NaN             NaN             NaN
# MABELLE HIATT             NaN             NaN             NaN             NaN
# ANNEMARIE MAGEE           NaN             NaN             NaN             NaN
# RAMONA BECK               NaN             NaN             NaN             NaN
# LORELEI MORELAND          NaN             NaN             NaN             NaN
# JANN LANKFORD             NaN             NaN             NaN             NaN
# KATHLENE TACKETT          NaN             NaN             NaN             NaN
# CAITLIN BASS              NaN             NaN             NaN             NaN
# YASMIN MILTON             NaN             NaN             NaN             NaN
# ERIKA WADE                NaN             NaN             NaN             NaN
# TRANG SLONE               NaN             NaN             NaN             NaN
# LYLA BOYKIN               NaN             NaN             NaN             NaN
# FELICE NEUMANN            NaN             NaN             NaN             NaN
# BECKIE THURSTON           NaN             NaN             NaN             NaN
# HEIDE TINSLEY             NaN             NaN             NaN             NaN
# VICENTA LOCKLEAR          NaN             NaN             NaN             NaN
# JEFFREY NOLAND            NaN             NaN             NaN             NaN
# JENELLE MINER             NaN             NaN             NaN             NaN
# ...                       ...             ...             ...             ...
# LAVONIA FIERRO         2830.0           713.0           353.0           353.0
# JOE ALBRIGHT           2831.0           713.0           353.0           353.0
# ROSANNE RICHMOND       2832.0           713.0           353.0           353.0
# DOLLIE ACEVEDO         2833.0           713.0           353.0           353.0
# ELMA STEPHENSON        2834.0           713.0           353.0           353.0
# EARLINE GAINES         2835.0           713.0           353.0           353.0
# LORINE SWARTZ          2836.0           713.0           353.0           353.0
# RAEANN GILLETTE        2837.0           713.0           353.0           353.0
# BELL BAGWELL              NaN             NaN             NaN             NaN
# STEFANY KNUDSEN        2839.0           713.0           353.0           353.0
# SONYA HALE                NaN             NaN             NaN             NaN
# MELONY BURGER          2841.0           713.0           372.0           372.0
# ANNIS BRISCOE          2842.0           713.0           372.0           372.0
# SACHIKO CHANCE            NaN             NaN             NaN             NaN
# KAROL THOMSON          2844.0           713.0           372.0           372.0
# AURA WESTON            2845.0           713.0           372.0           372.0
# PAOLA ALLRED           2846.0           713.0           372.0           372.0
# CAROLE BREWER          2847.0           713.0           372.0           372.0
# JACQUETTA WILLSON         NaN             NaN             NaN             NaN
# SANTANA YANCEY            NaN             NaN             NaN             NaN
# DAHLIA RUDD            2850.0           713.0           372.0           372.0
# DARCEY PALERMO         2851.0           713.0           372.0           372.0
# SHERY ELLINGTON           NaN             NaN             NaN             NaN
# MATHILDA JANSEN        2853.0           713.0           372.0           372.0
# SALLY WARREN              NaN             NaN             NaN             NaN
# MARSHA FULLER          2855.0           714.0           372.0           372.0
# KARIMA RANEY           2856.0           714.0           372.0           372.0
# JOSEFA SCHMITT            NaN             NaN             NaN             NaN
# MARGERT ROYER          2858.0             NaN             NaN           372.0
# MEGAN SHAW                NaN             NaN             NaN             NaN
#
#                    assistance_payout  assistance_put  assistance_request  \
# name
# JONE MEHTA                       NaN             NaN                 NaN
# MERRY CHAMBERLAIN                NaN             NaN                 NaN
# JEANNIE GIBBS                    NaN             NaN                 NaN
# KATHRYN REYES                    NaN             NaN                 NaN
# OCTAVIA GOFF                     NaN             NaN                 NaN
# TARA HUDSON                      NaN             NaN                 NaN
# LASANDRA ESPINO                  NaN             NaN                 NaN
# IRA LINK                         NaN             NaN                 NaN
# PIPER SKELTON                    NaN             NaN                 NaN
# MARINDA BROCKMAN                 NaN             NaN                 NaN
# ELSIE ELLIOTT                    NaN             NaN                 NaN
# EMILIA BUCKLEY                   NaN             NaN                 NaN
# AISHA PROCTOR                    NaN             NaN                 NaN
# MABELLE HIATT                    NaN             NaN                 NaN
# ANNEMARIE MAGEE                  NaN             NaN                 NaN
# RAMONA BECK                      NaN             NaN                 NaN
# LORELEI MORELAND                 NaN             NaN                 NaN
# JANN LANKFORD                    NaN             NaN                 NaN
# KATHLENE TACKETT                 NaN             NaN                 NaN
# CAITLIN BASS                     NaN             NaN                 NaN
# YASMIN MILTON                    NaN             NaN                 NaN
# ERIKA WADE                       NaN             NaN                 NaN
# TRANG SLONE                      NaN             NaN                 NaN
# LYLA BOYKIN                      NaN             NaN                 NaN
# FELICE NEUMANN                   NaN             NaN                 NaN
# BECKIE THURSTON                  NaN             NaN                 NaN
# HEIDE TINSLEY                    NaN             NaN                 NaN
# VICENTA LOCKLEAR                 NaN             NaN                 NaN
# JEFFREY NOLAND                   NaN             NaN                 NaN
# JENELLE MINER                    NaN             NaN                 NaN
# ...                              ...             ...                 ...
# LAVONIA FIERRO              2550.000            40.0            2550.000
# JOE ALBRIGHT               20887.500            40.0           20887.500
# ROSANNE RICHMOND           25875.000            40.0           25875.000
# DOLLIE ACEVEDO             26850.000            40.0           26850.000
# ELMA STEPHENSON            29662.500            40.0           29662.500
# EARLINE GAINES             28425.000            40.0           28425.000
# LORINE SWARTZ              21112.500            40.0           21112.500
# RAEANN GILLETTE            10537.500            40.0           10537.500
# BELL BAGWELL                     NaN             NaN                 NaN
# STEFANY KNUDSEN             3000.000            40.0            3000.000
# SONYA HALE                       NaN             NaN                 NaN
# MELONY BURGER              17625.000            40.0           17625.000
# ANNIS BRISCOE              11512.500            40.0           11512.500
# SACHIKO CHANCE                   NaN             NaN                 NaN
# KAROL THOMSON              20587.500            40.0           20587.500
# AURA WESTON                20850.000            40.0           20850.000
# PAOLA ALLRED                4100.000            40.0            4100.000
# CAROLE BREWER              45525.000            40.0           45525.000
# JACQUETTA WILLSON                NaN             NaN                 NaN
# SANTANA YANCEY                   NaN             NaN                 NaN
# DAHLIA RUDD                12975.000            40.0           12975.000
# DARCEY PALERMO                10.000            40.0              10.000
# SHERY ELLINGTON                  NaN             NaN                 NaN
# MATHILDA JANSEN            14653.425            40.0           14653.425
# SALLY WARREN                     NaN             NaN                 NaN
# MARSHA FULLER              46500.000            40.0           46500.000
# KARIMA RANEY                1987.500            40.0            1987.500
# JOSEFA SCHMITT                   NaN             NaN                 NaN
# MARGERT ROYER              19900.000            40.0           19900.000
# MEGAN SHAW                       NaN             NaN                 NaN
#
#                    claim_get  claim_payout  claim_put  \
# name
# JONE MEHTA               NaN           NaN        NaN
# MERRY CHAMBERLAIN        NaN           NaN        NaN
# JEANNIE GIBBS            NaN           NaN        NaN
# KATHRYN REYES            NaN           NaN        NaN
# OCTAVIA GOFF             NaN           NaN        NaN
# TARA HUDSON              NaN           NaN        NaN
# LASANDRA ESPINO          NaN           NaN        NaN
# IRA LINK                 NaN           NaN        NaN
# PIPER SKELTON            NaN           NaN        NaN
# MARINDA BROCKMAN         NaN           NaN        NaN
# ELSIE ELLIOTT            NaN           NaN        NaN
# EMILIA BUCKLEY           NaN           NaN        NaN
# AISHA PROCTOR            NaN           NaN        NaN
# MABELLE HIATT            NaN           NaN        NaN
# ANNEMARIE MAGEE          NaN           NaN        NaN
# RAMONA BECK              NaN           NaN        NaN
# LORELEI MORELAND         NaN           NaN        NaN
# JANN LANKFORD            NaN           NaN        NaN
# KATHLENE TACKETT         NaN           NaN        NaN
# CAITLIN BASS             NaN           NaN        NaN
# YASMIN MILTON            NaN           NaN        NaN
# ERIKA WADE               NaN           NaN        NaN
# TRANG SLONE              NaN           NaN        NaN
# LYLA BOYKIN              NaN           NaN        NaN
# FELICE NEUMANN           NaN           NaN        NaN
# BECKIE THURSTON          NaN           NaN        NaN
# HEIDE TINSLEY            NaN           NaN        NaN
# VICENTA LOCKLEAR         NaN           NaN        NaN
# JEFFREY NOLAND           NaN           NaN        NaN
# JENELLE MINER            NaN           NaN        NaN
# ...                      ...           ...        ...
# LAVONIA FIERRO           NaN           0.0        NaN
# JOE ALBRIGHT             NaN           0.0        NaN
# ROSANNE RICHMOND         NaN           0.0        NaN
# DOLLIE ACEVEDO           NaN           0.0        NaN
# ELMA STEPHENSON          NaN           0.0        NaN
# EARLINE GAINES           NaN           0.0        NaN
# LORINE SWARTZ            NaN           0.0        NaN
# RAEANN GILLETTE          NaN           0.0        NaN
# BELL BAGWELL             NaN           NaN        NaN
# STEFANY KNUDSEN          NaN           0.0        NaN
# SONYA HALE               NaN           NaN        NaN
# MELONY BURGER            NaN           0.0        NaN
# ANNIS BRISCOE            NaN           0.0        NaN
# SACHIKO CHANCE           NaN           NaN        NaN
# KAROL THOMSON            NaN           0.0        NaN
# AURA WESTON              NaN           0.0        NaN
# PAOLA ALLRED             NaN           0.0        NaN
# CAROLE BREWER            NaN           0.0        NaN
# JACQUETTA WILLSON        NaN           NaN        NaN
# SANTANA YANCEY           NaN           NaN        NaN
# DAHLIA RUDD              NaN           0.0        NaN
# DARCEY PALERMO           NaN           0.0        NaN
# SHERY ELLINGTON          NaN           NaN        NaN
# MATHILDA JANSEN          NaN           0.0        NaN
# SALLY WARREN             NaN           NaN        NaN
# MARSHA FULLER            NaN           0.0        NaN
# KARIMA RANEY             NaN           0.0        NaN
# JOSEFA SCHMITT           NaN           NaN        NaN
# MARGERT ROYER            NaN           0.0        NaN
# MEGAN SHAW               NaN           NaN        NaN
#
#                                          ...                          \
# name                                     ...
# JONE MEHTA                               ...
# MERRY CHAMBERLAIN                        ...
# JEANNIE GIBBS                            ...
# KATHRYN REYES                            ...
# OCTAVIA GOFF                             ...
# TARA HUDSON                              ...
# LASANDRA ESPINO                          ...
# IRA LINK                                 ...
# PIPER SKELTON                            ...
# MARINDA BROCKMAN                         ...
# ELSIE ELLIOTT                            ...
# EMILIA BUCKLEY                           ...
# AISHA PROCTOR                            ...
# MABELLE HIATT                            ...
# ANNEMARIE MAGEE                          ...
# RAMONA BECK                              ...
# LORELEI MORELAND                         ...
# JANN LANKFORD                            ...
# KATHLENE TACKETT                         ...
# CAITLIN BASS                             ...
# YASMIN MILTON                            ...
# ERIKA WADE                               ...
# TRANG SLONE                              ...
# LYLA BOYKIN                              ...
# FELICE NEUMANN                           ...
# BECKIE THURSTON                          ...
# HEIDE TINSLEY                            ...
# VICENTA LOCKLEAR                         ...
# JEFFREY NOLAND                           ...
# JENELLE MINER                            ...
# ...                                      ...
# LAVONIA FIERRO                           ...
# JOE ALBRIGHT                             ...
# ROSANNE RICHMOND                         ...
# DOLLIE ACEVEDO                           ...
# ELMA STEPHENSON                          ...
# EARLINE GAINES                           ...
# LORINE SWARTZ                            ...
# RAEANN GILLETTE                          ...
# BELL BAGWELL                             ...
# STEFANY KNUDSEN                          ...
# SONYA HALE                               ...
# MELONY BURGER                            ...
# ANNIS BRISCOE                            ...
# SACHIKO CHANCE                           ...
# KAROL THOMSON                            ...
# AURA WESTON                              ...
# PAOLA ALLRED                             ...
# CAROLE BREWER                            ...
# JACQUETTA WILLSON                        ...
# SANTANA YANCEY                           ...
# DAHLIA RUDD                              ...
# DARCEY PALERMO                           ...
# SHERY ELLINGTON                          ...
# MATHILDA JANSEN                          ...
# SALLY WARREN                             ...
# MARSHA FULLER                            ...
# KARIMA RANEY                             ...
# JOSEFA SCHMITT                           ...
# MARGERT ROYER                            ...
# MEGAN SHAW                               ...
#
#                    loan_put   longitude  money_search_start  \
# name
# JONE MEHTA              NaN         NaN                 NaN
# MERRY CHAMBERLAIN       NaN         NaN                 NaN
# JEANNIE GIBBS           NaN         NaN                 NaN
# KATHRYN REYES           NaN         NaN                 NaN
# OCTAVIA GOFF            NaN         NaN                 NaN
# TARA HUDSON             NaN         NaN                 NaN
# LASANDRA ESPINO         NaN         NaN                 NaN
# IRA LINK                NaN         NaN                 NaN
# PIPER SKELTON           NaN         NaN                 NaN
# MARINDA BROCKMAN        NaN         NaN                 NaN
# ELSIE ELLIOTT           NaN         NaN                 NaN
# EMILIA BUCKLEY          NaN         NaN                 NaN
# AISHA PROCTOR           NaN         NaN                 NaN
# MABELLE HIATT           NaN         NaN                 NaN
# ANNEMARIE MAGEE         NaN         NaN                 NaN
# RAMONA BECK             NaN         NaN                 NaN
# LORELEI MORELAND        NaN         NaN                 NaN
# JANN LANKFORD           NaN         NaN                 NaN
# KATHLENE TACKETT        NaN         NaN                 NaN
# CAITLIN BASS            NaN         NaN                 NaN
# YASMIN MILTON           NaN         NaN                 NaN
# ERIKA WADE              NaN         NaN                 NaN
# TRANG SLONE             NaN         NaN                 NaN
# LYLA BOYKIN             NaN         NaN                 NaN
# FELICE NEUMANN          NaN         NaN                 NaN
# BECKIE THURSTON         NaN         NaN                 NaN
# HEIDE TINSLEY           NaN         NaN                 NaN
# VICENTA LOCKLEAR        NaN         NaN                 NaN
# JEFFREY NOLAND          NaN         NaN                 NaN
# JENELLE MINER           NaN         NaN                 NaN
# ...                     ...         ...                 ...
# LAVONIA FIERRO          NaN -123.736584                40.0
# JOE ALBRIGHT            NaN -124.054916                40.0
# ROSANNE RICHMOND        NaN -124.050363                40.0
# DOLLIE ACEVEDO          NaN -124.038796                40.0
# ELMA STEPHENSON         NaN -124.032683                40.0
# EARLINE GAINES          NaN -124.049786                40.0
# LORINE SWARTZ           NaN -124.043943                40.0
# RAEANN GILLETTE         NaN -123.744870                40.0
# BELL BAGWELL            NaN         NaN                 NaN
# STEFANY KNUDSEN         NaN -124.052932                40.0
# SONYA HALE              NaN         NaN                 NaN
# MELONY BURGER           NaN -124.056443                40.0
# ANNIS BRISCOE           NaN -124.037605                40.0
# SACHIKO CHANCE          NaN         NaN                 NaN
# KAROL THOMSON           NaN -124.039392                40.0
# AURA WESTON             NaN -124.023826                40.0
# PAOLA ALLRED            NaN -124.057317                40.0
# CAROLE BREWER           NaN -124.053848                40.0
# JACQUETTA WILLSON       NaN         NaN                 NaN
# SANTANA YANCEY          NaN         NaN                 NaN
# DAHLIA RUDD             NaN -124.041750                40.0
# DARCEY PALERMO          NaN -124.054931                40.0
# SHERY ELLINGTON         NaN         NaN                 NaN
# MATHILDA JANSEN         NaN -124.053749                40.0
# SALLY WARREN            NaN         NaN                 NaN
# MARSHA FULLER           NaN -124.031361                40.0
# KARIMA RANEY            NaN -123.628591                40.0
# JOSEFA SCHMITT          NaN         NaN                 NaN
# MARGERT ROYER           NaN -123.740398                40.0
# MEGAN SHAW              NaN         NaN                 NaN
#
#                    money_search_stop  money_to_rebuild              name  \
# name
# JONE MEHTA                       NaN               NaN               NaN
# MERRY CHAMBERLAIN                NaN               NaN               NaN
# JEANNIE GIBBS                    NaN               NaN               NaN
# KATHRYN REYES                    NaN               NaN               NaN
# OCTAVIA GOFF                     NaN               NaN               NaN
# TARA HUDSON                      NaN               NaN               NaN
# LASANDRA ESPINO                  NaN               NaN               NaN
# IRA LINK                         NaN               NaN               NaN
# PIPER SKELTON                    NaN               NaN               NaN
# MARINDA BROCKMAN                 NaN               NaN               NaN
# ELSIE ELLIOTT                    NaN               NaN               NaN
# EMILIA BUCKLEY                   NaN               NaN               NaN
# AISHA PROCTOR                    NaN               NaN               NaN
# MABELLE HIATT                    NaN               NaN               NaN
# ANNEMARIE MAGEE                  NaN               NaN               NaN
# RAMONA BECK                      NaN               NaN               NaN
# LORELEI MORELAND                 NaN               NaN               NaN
# JANN LANKFORD                    NaN               NaN               NaN
# KATHLENE TACKETT                 NaN               NaN               NaN
# CAITLIN BASS                     NaN               NaN               NaN
# YASMIN MILTON                    NaN               NaN               NaN
# ERIKA WADE                       NaN               NaN               NaN
# TRANG SLONE                      NaN               NaN               NaN
# LYLA BOYKIN                      NaN               NaN               NaN
# FELICE NEUMANN                   NaN               NaN               NaN
# BECKIE THURSTON                  NaN               NaN               NaN
# HEIDE TINSLEY                    NaN               NaN               NaN
# VICENTA LOCKLEAR                 NaN               NaN               NaN
# JEFFREY NOLAND                   NaN               NaN               NaN
# JENELLE MINER                    NaN               NaN               NaN
# ...                              ...               ...               ...
# LAVONIA FIERRO                 353.0       5062.406766    LAVONIA FIERRO
# JOE ALBRIGHT                   353.0      24375.715479      JOE ALBRIGHT
# ROSANNE RICHMOND               353.0      29638.062409  ROSANNE RICHMOND
# DOLLIE ACEVEDO                 353.0      30662.989054    DOLLIE ACEVEDO
# ELMA STEPHENSON                353.0      33616.479571   ELMA STEPHENSON
# EARLINE GAINES                 353.0      32308.201923    EARLINE GAINES
# LORINE SWARTZ                  353.0      24619.963988     LORINE SWARTZ
# RAEANN GILLETTE                353.0      13122.257679   RAEANN GILLETTE
# BELL BAGWELL                     NaN               NaN               NaN
# STEFANY KNUDSEN                353.0       4551.790046   STEFANY KNUDSEN
# SONYA HALE                       NaN               NaN               NaN
# MELONY BURGER                  372.0      20870.546863     MELONY BURGER
# ANNIS BRISCOE                  372.0      14184.129755     ANNIS BRISCOE
# SACHIKO CHANCE                   NaN               NaN               NaN
# KAROL THOMSON                  372.0      24045.328570     KAROL THOMSON
# AURA WESTON                    372.0      24333.932760       AURA WESTON
# PAOLA ALLRED                   372.0       7157.002651      PAOLA ALLRED
# CAROLE BREWER                  372.0      50000.913725     CAROLE BREWER
# JACQUETTA WILLSON                NaN               NaN               NaN
# SANTANA YANCEY                   NaN               NaN               NaN
# DAHLIA RUDD                    372.0      15779.936131       DAHLIA RUDD
# DARCEY PALERMO                 372.0         10.000000    DARCEY PALERMO
# SHERY ELLINGTON                  NaN               NaN               NaN
# MATHILDA JANSEN                372.0      17632.346325   MATHILDA JANSEN
# SALLY WARREN                     NaN               NaN               NaN
# MARSHA FULLER                  372.0      50999.279545     MARSHA FULLER
# KARIMA RANEY                   372.0       3043.257683      KARIMA RANEY
# JOSEFA SCHMITT                   NaN               NaN               NaN
# MARGERT ROYER                  372.0      22161.010277     MARGERT ROYER
# MEGAN SHAW                       NaN               NaN               NaN
#
#                    permit_get  permit_put      savings  \
# name
# JONE MEHTA                NaN         NaN          NaN
# MERRY CHAMBERLAIN         NaN         NaN          NaN
# JEANNIE GIBBS             NaN         NaN          NaN
# KATHRYN REYES             NaN         NaN          NaN
# OCTAVIA GOFF              NaN         NaN          NaN
# TARA HUDSON               NaN         NaN          NaN
# LASANDRA ESPINO           NaN         NaN          NaN
# IRA LINK                  NaN         NaN          NaN
# PIPER SKELTON             NaN         NaN          NaN
# MARINDA BROCKMAN          NaN         NaN          NaN
# ELSIE ELLIOTT             NaN         NaN          NaN
# EMILIA BUCKLEY            NaN         NaN          NaN
# AISHA PROCTOR             NaN         NaN          NaN
# MABELLE HIATT             NaN         NaN          NaN
# ANNEMARIE MAGEE           NaN         NaN          NaN
# RAMONA BECK               NaN         NaN          NaN
# LORELEI MORELAND          NaN         NaN          NaN
# JANN LANKFORD             NaN         NaN          NaN
# KATHLENE TACKETT          NaN         NaN          NaN
# CAITLIN BASS              NaN         NaN          NaN
# YASMIN MILTON             NaN         NaN          NaN
# ERIKA WADE                NaN         NaN          NaN
# TRANG SLONE               NaN         NaN          NaN
# LYLA BOYKIN               NaN         NaN          NaN
# FELICE NEUMANN            NaN         NaN          NaN
# BECKIE THURSTON           NaN         NaN          NaN
# HEIDE TINSLEY             NaN         NaN          NaN
# VICENTA LOCKLEAR          NaN         NaN          NaN
# JEFFREY NOLAND            NaN         NaN          NaN
# JENELLE MINER             NaN         NaN          NaN
# ...                       ...         ...          ...
# LAVONIA FIERRO         1018.0       713.0  2512.406766
# JOE ALBRIGHT           1018.0       713.0  3488.215479
# ROSANNE RICHMOND       1018.0       713.0  3763.062409
# DOLLIE ACEVEDO         1018.0       713.0  3812.989054
# ELMA STEPHENSON        1018.0       713.0  3953.979571
# EARLINE GAINES         1018.0       713.0  3883.201923
# LORINE SWARTZ          1018.0       713.0  3507.463988
# RAEANN GILLETTE        1018.0       713.0  2584.757679
# BELL BAGWELL              NaN         NaN          NaN
# STEFANY KNUDSEN        1018.0       713.0  1551.790046
# SONYA HALE                NaN         NaN          NaN
# MELONY BURGER          1018.0       713.0  3245.546863
# ANNIS BRISCOE          1018.0       713.0  2671.629755
# SACHIKO CHANCE            NaN         NaN          NaN
# KAROL THOMSON          1018.0       713.0  3457.828570
# AURA WESTON            1018.0       713.0  3483.932760
# PAOLA ALLRED           1018.0       713.0  3057.002651
# CAROLE BREWER          1018.0       713.0  4475.913725
# JACQUETTA WILLSON         NaN         NaN          NaN
# SANTANA YANCEY            NaN         NaN          NaN
# DAHLIA RUDD            1018.0       713.0  2804.936131
# DARCEY PALERMO         1018.0       713.0     0.000000
# SHERY ELLINGTON           NaN         NaN          NaN
# MATHILDA JANSEN        1018.0       713.0  2978.921325
# SALLY WARREN              NaN         NaN          NaN
# MARSHA FULLER          1019.0       714.0  4499.279545
# KARIMA RANEY           1019.0       714.0  1055.757683
# JOSEFA SCHMITT            NaN         NaN          NaN
# MARGERT ROYER             NaN         NaN  2261.010277
# MEGAN SHAW                NaN         NaN          NaN
#
#                                                                story
# name
# JONE MEHTA                                                       NaN
# MERRY CHAMBERLAIN                                                NaN
# JEANNIE GIBBS                                                    NaN
# KATHRYN REYES                                                    NaN
# OCTAVIA GOFF                                                     NaN
# TARA HUDSON                                                      NaN
# LASANDRA ESPINO                                                  NaN
# IRA LINK                                                         NaN
# PIPER SKELTON                                                    NaN
# MARINDA BROCKMAN                                                 NaN
# ELSIE ELLIOTT                                                    NaN
# EMILIA BUCKLEY                                                   NaN
# AISHA PROCTOR                                                    NaN
# MABELLE HIATT                                                    NaN
# ANNEMARIE MAGEE                                                  NaN
# RAMONA BECK                                                      NaN
# LORELEI MORELAND                                                 NaN
# JANN LANKFORD                                                    NaN
# KATHLENE TACKETT                                                 NaN
# CAITLIN BASS                                                     NaN
# YASMIN MILTON                                                    NaN
# ERIKA WADE                                                       NaN
# TRANG SLONE                                                      NaN
# LYLA BOYKIN                                                      NaN
# FELICE NEUMANN                                                   NaN
# BECKIE THURSTON                                                  NaN
# HEIDE TINSLEY                                                    NaN
# VICENTA LOCKLEAR                                                 NaN
# JEFFREY NOLAND                                                   NaN
# JENELLE MINER                                                    NaN
# ...                                                              ...
# LAVONIA FIERRO     ['Lavonia Fierro lives in a 2 bedroom Single F...
# JOE ALBRIGHT       ['Joe Albright lives in a 2 bedroom Mobile Hom...
# ROSANNE RICHMOND   ['Rosanne Richmond lives in a 4 bedroom Mobile...
# DOLLIE ACEVEDO     ['Dollie Acevedo lives in a 3 bedroom Mobile H...
# ELMA STEPHENSON    ['Elma Stephenson lives in a 2 bedroom Mobile ...
# EARLINE GAINES     ['Earline Gaines lives in a 5 bedroom Mobile H...
# LORINE SWARTZ      ['Lorine Swartz lives in a 3 bedroom Mobile Ho...
# RAEANN GILLETTE    ['Raeann Gillette lives in a 3 bedroom Mobile ...
# BELL BAGWELL                                                     NaN
# STEFANY KNUDSEN    ['Stefany Knudsen lives in a 3 bedroom Mobile ...
# SONYA HALE                                                       NaN
# MELONY BURGER      ['Melony Burger lives in a 2 bedroom Mobile Ho...
# ANNIS BRISCOE      ['Annis Briscoe lives in a 5 bedroom Mobile Ho...
# SACHIKO CHANCE                                                   NaN
# KAROL THOMSON      ['Karol Thomson lives in a 5 bedroom Mobile Ho...
# AURA WESTON        ['Aura Weston lives in a 2 bedroom Mobile Home...
# PAOLA ALLRED       ['Paola Allred lives in a 3 bedroom Single Fam...
# CAROLE BREWER      ['Carole Brewer lives in a 3 bedroom Mobile Ho...
# JACQUETTA WILLSON                                                NaN
# SANTANA YANCEY                                                   NaN
# DAHLIA RUDD        ['Dahlia Rudd lives in a 5 bedroom Mobile Home...
# DARCEY PALERMO     ['Darcey Palermo lives in a 2 bedroom Single F...
# SHERY ELLINGTON                                                  NaN
# MATHILDA JANSEN    ['Mathilda Jansen lives in a 5 bedroom Mobile ...
# SALLY WARREN                                                     NaN
# MARSHA FULLER      ['Marsha Fuller lives in a 2 bedroom Mobile Ho...
# KARIMA RANEY       ['Karima Raney lives in a 3 bedroom Mobile Hom...
# JOSEFA SCHMITT                                                   NaN
# MARGERT ROYER      ['Margert Royer lives in a 2 bedroom Mobile Ho...
# MEGAN SHAW                                                       NaN
#
# [2860 rows x 32 columns]

# %%
namedf.ix[name].story
# Out:
# '[\'Marsha Fuller lives in a 2 bedroom Mobile Home at None worth $124,000. Its damage level from the event was Extensive.\', "Marsha Fuller\'s house was inspected 40 days after the event and suffered $46,500 of damage. ", \'Marsha Fuller submitted a request to FEMA 40 days after the event. \', \'Marsha Fuller received $46,500 from FEMA 372 days after the event. \', \'It took Marsha Fuller 332 days to receive enough financial assistance and now has $50,999 to rebuild. \', \'Marsha Fuller received an engineering assessment 714 days after the event. \', \'Marsha Fuller received permit approval 1019 days after the event. \', "Marsha Fuller\'s home was repaired 1,049 days after the event, taking 30 days to repair. "]'

# %%
name = namedf.ix[name][['inspection_put',
 'inspection_get',
 'money_search_start',
 'money_search_stop',
 'claim_put',
 'claim_get',
 'assistance_put',
 'assistance_get',
 'assessment_put',
 'assessment_get',
 'permit_put',
 'permit_get',
 'home_put',
 'home_get'
]]

# %%
# %matplotlib inline
plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
sns.set(font_scale=2)
ax = sns.stripplot(y=name.index, x=name, jitter=True, size = 15, linewidth=1)
ax.set(xlabel='Days After Event', ylabel='Housing Recovery Event')
# Out:
# [<matplotlib.text.Text at 0x1203d7898>, <matplotlib.text.Text at 0x12086a320>]

# %%
Generate graphs that we can paste into powerpoint
# Out:
#   File "<ipython-input-10-659dbf7f3364>", line 1
#     Generate graphs that we can paste into powerpoint
#                   ^
# SyntaxError: invalid syntax

# %%
name2 = "GENEVIEVE BENSON"
name2 = namedf.ix[name2][['inspection_put',
 'inspection_get',
 'money_search_start',
 'money_search_stop',
 'claim_put',
 'claim_get',
 'assistance_put',
 'assistance_get',
 'assessment_put',
 'assessment_get',
 'permit_put',
 'permit_get',
 'home_put',
 'home_get'
]]

# %%
plt.figure(figsize=(10,10))
sns.stripplot(y=name2.index, x=name2, jitter=0, size = 30,linewidth=2, palette='pastel', edgecolor="black")
sns.stripplot(y=name.index, x=name, jitter=0, size = 20,linewidth=2, palette='bright', edgecolor = "red")
